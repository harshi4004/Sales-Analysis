# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv('Diwali_Sales_Data.csv',encoding = 'unicode_escape')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# ## Dataset
# [Diwali sales Analysis data set](Diwali_Sales_Data.csv)

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11251, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            11251 non-null  object
#  14  unnamed1          0 non-null      float64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 1.3+ MB

# %%
df.drop(['unnamed1'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (11251, 14)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status'],
#       dtype='object')

# %%
df.head(15)
# Out:
#     User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903  Sanskriti  P00125942      F     26-35   28               0
# 1   1000732     Kartik  P00110942      F     26-35   35               1
# 2   1001990      Bindu  P00118542      F     26-35   35               1
# 3   1001425     Sudevi  P00237842      M      0-17   16               0
# 4   1000588       Joni  P00057942      M     26-35   28               1
# 5   1000588       Joni  P00057942      M     26-35   28               1
# 6   1001132       Balk  P00018042      F     18-25   25               1
# 7   1002092   Shivangi  P00273442      F       55+   61               0
# 8   1003224     Kushal  P00205642      M     26-35   35               0
# 9   1003650      Ginny  P00031142      F     26-35   26               1
# 10  1003829   Harshita  P00200842      M     26-35   34               0
# 11  1000214   Kargatis  P00119142      F     18-25   20               0
# ...

# %%
df.tail(5)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#            Status
# ...

# %%
df['Status'].value_counts()
# Out:
# Successful    11120
# Failed          131
# Name: Status, dtype: int64

# %%
df['State'].value_counts()
# Out:
# Uttar Pradesh       1946
# Maharashtra         1526
# Karnataka           1305
# Delhi               1107
# Madhya Pradesh       923
# Andhra Pradesh       812
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              429
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: State, dtype: int64

# %% [markdown]
# ### DataCleaning:

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# Status               0
# dtype: int64

# %%
pd.notnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group   Age  \
# 0         True       True        True    True       True  True
# 1         True       True        True    True       True  True
# 2         True       True        True    True       True  True
# 3         True       True        True    True       True  True
# 4         True       True        True    True       True  True
# ...        ...        ...         ...     ...        ...   ...
# 11246     True       True        True    True       True  True
# 11247     True       True        True    True       True  True
# 11248     True       True        True    True       True  True
# 11249     True       True        True    True       True  True
# 11250     True       True        True    True       True  True
#
#        Marital_Status  State  Zone  Occupation  Product_Category  Orders  \
# 0                True   True  True        True              True    True
# ...

# %%
pd.notnull(df).sum()
# Out:
# User_ID             11251
# Cust_name           11251
# Product_ID          11251
# Gender              11251
# Age Group           11251
# Age                 11251
# Marital_Status      11251
# State               11251
# Zone                11251
# Occupation          11251
# Product_Category    11251
# Orders              11251
# Amount              11239
# Status              11251
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
#  13  Status            11239 non-null  object
# dtypes: int32(1), int64(4), object(9)
# memory usage: 1.2+ MB

# %%
# 4. fillna(): To fill the null values with meaningfull data.
df.fillna('none',inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# replace(): to replace the data
df.replace(to_replace='M',value='MALE',inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842   MALE      0-17   16               0
# 4      1000588         Joni  P00057942   MALE     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942   MALE     18-25   19               1
# 11247  1004089  Reichenbach  P00171342   MALE     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442   MALE     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# replace(): to replace the data
df.replace(to_replace='F',value='FEMALE',inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  FEMALE     26-35   28               0
# 1      1000732       Kartik  P00110942  FEMALE     26-35   35               1
# 2      1001990        Bindu  P00118542  FEMALE     26-35   35               1
# 3      1001425       Sudevi  P00237842    MALE      0-17   16               0
# 4      1000588         Joni  P00057942    MALE     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      Manning  P00296942    MALE     18-25   19               1
# 11247  1004089  Reichenbach  P00171342    MALE     26-35   33               0
# 11248  1001209        Oshin  P00201342  FEMALE     36-45   40               0
# 11249  1004023       Noonan  P00059442    MALE     36-45   37               0
# 11250  1002744      Brumley  P00281742  FEMALE     18-25   19               0
#
# ...

# %%
df['Amount'].replace(to_replace=[23912],value=[14300],inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  FEMALE     26-35   28               0
# 1      1000732       Kartik  P00110942  FEMALE     26-35   35               1
# 2      1001990        Bindu  P00118542  FEMALE     26-35   35               1
# 3      1001425       Sudevi  P00237842    MALE      0-17   16               0
# 4      1000588         Joni  P00057942    MALE     26-35   28               1
# ...        ...          ...        ...     ...       ...  ...             ...
# 11246  1000695      Manning  P00296942    MALE     18-25   19               1
# 11247  1004089  Reichenbach  P00171342    MALE     26-35   33               0
# 11248  1001209        Oshin  P00201342  FEMALE     36-45   40               0
# 11249  1004023       Noonan  P00059442    MALE     36-45   37               0
# 11250  1002744      Brumley  P00281742  FEMALE     18-25   19               0
#
# ...

# %%
df.rename(columns={'Age Group':'Age_Grp'},inplace=True)
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  FEMALE   26-35   28               0
# 1      1000732       Kartik  P00110942  FEMALE   26-35   35               1
# 2      1001990        Bindu  P00118542  FEMALE   26-35   35               1
# 3      1001425       Sudevi  P00237842    MALE    0-17   16               0
# 4      1000588         Joni  P00057942    MALE   26-35   28               1
# ...        ...          ...        ...     ...     ...  ...             ...
# 11246  1000695      Manning  P00296942    MALE   18-25   19               1
# 11247  1004089  Reichenbach  P00171342    MALE   26-35   33               0
# 11248  1001209        Oshin  P00201342  FEMALE   36-45   40               0
# 11249  1004023       Noonan  P00059442    MALE   36-45   37               0
# 11250  1002744      Brumley  P00281742  FEMALE   18-25   19               0
#
# ...

# %%
### updating to original file
df.to_csv('Diwali_Sales_Data.csv',index=False) 
df
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942  FEMALE   26-35   28               0
# 1      1000732       Kartik  P00110942  FEMALE   26-35   35               1
# 2      1001990        Bindu  P00118542  FEMALE   26-35   35               1
# 3      1001425       Sudevi  P00237842    MALE    0-17   16               0
# 4      1000588         Joni  P00057942    MALE   26-35   28               1
# ...        ...          ...        ...     ...     ...  ...             ...
# 11246  1000695      Manning  P00296942    MALE   18-25   19               1
# 11247  1004089  Reichenbach  P00171342    MALE   26-35   33               0
# 11248  1001209        Oshin  P00201342  FEMALE   36-45   40               0
# 11249  1004023       Noonan  P00059442    MALE   36-45   37               0
# 11250  1002744      Brumley  P00281742  FEMALE   18-25   19               0
#
# ...

# %% [markdown]
# ### Sorting

# %%
df.sort_values('Cust_name')
# Out:
#        User_ID Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 1497   1001407     Aaron  P00219942    MALE   36-45   41               1
# 8508   1001407     Aaron  P00125742    MALE   36-45   37               1
# 10329  1001407     Aaron  P00184942    MALE   36-45   38               0
# 7561   1000420     Aaron  P00136842  FEMALE   36-45   45               0
# 10500  1005406     Aaron  P00174042    MALE   36-45   39               1
# ...        ...       ...        ...     ...     ...  ...             ...
# 9954   1004821    percer  P00047042    MALE   18-25   21               0
# 9408   1004090    percer  P00233442    MALE     55+   63               1
# 4627   1002664    percer  P00110942  FEMALE   36-45   37               1
# 368    1002664    percer  P00090942    MALE   36-45   45               0
# 1874   1002664    percer  P00221142  FEMALE   36-45   38               0
#
#                   State      Zone    Occupation       Product_Category  \
# ...

# %%
df.sort_values('Age',ascending=False)
# Out:
#        User_ID Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 2951   1002204   Dilbeck  P00246642    MALE     55+   92               0
# 359    1003036  Prescott  P00255842  FEMALE     55+   92               0
# 9412   1000928    Hemant  P00134342    MALE     55+   92               0
# 2698   1005658   Poirier  P00227942    MALE     55+   92               0
# 9956   1002676    Jitesh  P00204742  FEMALE     55+   92               0
# ...        ...       ...        ...     ...     ...  ...             ...
# 8990   1002060      Lynn  P00274942  FEMALE    0-17   12               0
# 3606   1001296      Nunn  P00364842  FEMALE    0-17   12               0
# 1561   1001434    Steven  P00265242  FEMALE    0-17   12               0
# 10774  1001926    Barton  P00157542    MALE    0-17   12               1
# 4725   1001926    Barton  P00152442    MALE    0-17   12               0
#
#                   State      Zone    Occupation       Product_Category  \
# ...

# %%
df.sort_values(by="User_ID")
# Out:
#       User_ID  Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 9528  1000001      Chris  P00059442  FEMALE    0-17   13               1
# 6993  1000002  Latchford  P00115342  FEMALE     55+   56               0
# 3771  1000003      Sabah  P00058042  FEMALE   26-35   35               0
# 2993  1000003      Sabah  P00241642  FEMALE   26-35   33               0
# 4048  1000004    Guthrie  P00318742  FEMALE   46-50   47               1
# ...       ...        ...        ...     ...     ...  ...             ...
# 8201  1006039      Harry  P00035542    MALE   46-50   48               0
# 7693  1006040       Pond  P00271042  FEMALE   26-35   31               1
# 83    1006040       Pond  P00271242  FEMALE   26-35   28               1
# 255   1006040       Pond  P00111142  FEMALE   26-35   27               0
# 2487  1006040       Pond  P00211242  FEMALE   26-35   27               0
#
#                State      Zone       Occupation       Product_Category  \
# ...

# %%
df[(df['Age']>50) & (df['Amount']>15000)]
# Out:
#       User_ID Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 18    1001883   Praneet  P00029842    MALE   51-55   54               1
# 19    1001883   Praneet  P00029842    MALE   51-55   54               1
# 23    1001505  Gilcrest  P00271842  FEMALE   51-55   53               0
# 24    1000900    Skaria  P00317842    MALE     55+   83               0
# 28    1004037   Etezadi  P00190542    MALE   51-55   54               1
# ...       ...       ...        ...     ...     ...  ...             ...
# 2395  1002049    Ludwig  P00126442    MALE   51-55   51               0
# 2417  1003476    Lalita  P00266542  FEMALE   51-55   55               0
# 2438  1004084   Tillman  P00229942  FEMALE     55+   80               0
# 2439  1002870      Eric  P00048442    MALE   51-55   53               1
# 2442  1002334   Moumita  P00339842    MALE     55+   61               1
#
#                State      Zone    Occupation    Product_Category  Orders  \
# ...

# %%
df.sort_values('Age_Grp')
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 6045   1000119        Roger   P0095842    MALE    0-17   12               0
# 1200   1000075          Ted  P00137642    MALE    0-17   15               0
# 6184   1001928       Ferrer  P00113042  FEMALE    0-17   12               0
# 2378   1005420  Französisch  P00156842  FEMALE    0-17   13               0
# 6145   1001241         Amol  P00062842  FEMALE    0-17   14               0
# ...        ...          ...        ...     ...     ...  ...             ...
# 5397   1002699       Nikhil  P00362642    MALE     55+   79               0
# 7119   1002069     Cacioppo  P00018442  FEMALE     55+   65               0
# 5480   1001772        Weien  P00186142  FEMALE     55+   58               1
# 10926  1005431       Sample  P00154742  FEMALE     55+   90               0
# 8025   1002016    Manibalan  P00249742    MALE     55+   89               0
#
# ...

# %% [markdown]
# ### Filtering

# %%
df['Amount'].max()
# Out:
# 23952

# %%
df['Amount'].min()
# Out:
# 188

# %%
df[df['Zone']=='Southern']
# Out:
#        User_ID Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 1      1000732    Kartik  P00110942  FEMALE   26-35   35               1
# 3      1001425    Sudevi  P00237842    MALE    0-17   16               0
# 9      1003650     Ginny  P00031142  FEMALE   26-35   26               1
# 11     1000214  Kargatis  P00119142  FEMALE   18-25   20               0
# 12     1004035    Elijah  P00080342  FEMALE   18-25   20               1
# ...        ...       ...        ...     ...     ...  ...             ...
# 11200  1000814     Hwang  P00144042    MALE   18-25   19               0
# 11218  1003606       Meg  P00157542    MALE   26-35   32               0
# 11235  1001248   Calhoun  P00255842    MALE   36-45   39               0
# 11238  1002718  Abhishek  P00003442    MALE   26-35   28               0
# 11249  1004023    Noonan  P00059442    MALE   36-45   37               0
#
#                 State      Zone    Occupation Product_Category  Orders  \
# ...

# %%
df[df['Cust_name'].str.startswith('B')]
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 2      1001990        Bindu  P00118542  FEMALE   26-35   35               1
# 6      1001132         Balk  P00018042  FEMALE   18-25   25               1
# 46     1000728       Breyer  P00113942  FEMALE   26-35   28               0
# 62     1001687        Bruce  P00265242  FEMALE   26-35   33               0
# 73     1000438      Bhosale  P00182542  FEMALE   18-25   25               0
# ...        ...          ...        ...     ...     ...  ...             ...
# 11199  1002247  Bhaggyasree  P00086642    MALE   46-50   50               0
# 11203  1000045         Byrd  P00205942    MALE   46-50   49               1
# 11223  1001542         Buch  P00113642  FEMALE   18-25   20               1
# 11245  1004140    Bertelson  P00057442  FEMALE   26-35   31               1
# 11250  1002744      Brumley  P00281742  FEMALE   18-25   19               0
#
# ...

# %%
print(len(df[df['Cust_name'].str.startswith('B')]))
# Out:
# 864

# %%
df[df['Status']=='Failed']
# Out:
#        User_ID    Cust_name Product_ID  Gender Age_Grp  Age  Marital_Status  \
# 8095   1004726       Alyssa  P00048442    MALE   36-45   38               0
# 8579   1003945       Mrunal  P00187342    MALE   46-50   50               0
# 8580   1002929     Bhutekar  P00036842  FEMALE   18-25   19               0
# 8581   1001624    Hightower  P00274242  FEMALE   26-35   33               1
# 8582   1002661         Hart  P00222142  FEMALE     55+   79               0
# ...        ...          ...        ...     ...     ...  ...             ...
# 11188  1000150         Toch  P00217742  FEMALE   36-45   42               1
# 11189  1004626  Soumyabrata  P00121942  FEMALE   26-35   27               1
# 11190  1005874       Irving  P00184942  FEMALE   26-35   28               1
# 11191  1003626       Kartik  P00114142  FEMALE   26-35   34               1
# 11192  1002368        Sonia  P00329642    MALE     55+   67               0
#
# ...

# %%
print(len(df[df['Product_ID'] == 'P00125942']))
# Out:
# 18

# %%
df['Product_ID'].value_counts()
# Out:
# P00265242    53
# P00110942    44
# P00184942    37
# P00237542    35
# P00112142    34
#              ..
# P00257642     1
# P00078242     1
# P00333542     1
# P00206642     1
# P00296942     1
# Name: Product_ID, Length: 2350, dtype: int64

# %%
print(len(df['Product_ID'].value_counts()))
# Out:
# 2350

# %%
df['Product_Category'].value_counts()
# Out:
# Clothing & Apparel       2655
# Food                     2490
# Electronics & Gadgets    2087
# Footwear & Shoes         1059
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 352
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                       97
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: Product_Category, dtype: int64

# %% [markdown]
# ### Grouping

# %%
gp = df.groupby('Product_ID')
gp

# %%
gp.ngroups
# Out:
# 2350

# %%
gp = df.groupby("State")["Zone"].count()
gp.head(10)
# Out:
# State
# Andhra Pradesh       811
# Bihar                434
# Delhi               1104
# Gujarat              427
# Haryana              452
# Himachal Pradesh     608
# Jharkhand            380
# Karnataka           1304
# Kerala               453
# Madhya Pradesh       921
# Name: Zone, dtype: int64

# %%
df.groupby("State",sort=False).count()
# Out:
#                   User_ID  Cust_name  Product_ID  Gender  Age_Grp   Age  \
# State
# Maharashtra          1525       1525        1525    1525     1525  1525
# Andhra Pradesh        811        811         811     811      811   811
# Uttar Pradesh        1944       1944        1944    1944     1944  1944
# Karnataka            1304       1304        1304    1304     1304  1304
# Gujarat               427        427         427     427      427   427
# Himachal Pradesh      608        608         608     608      608   608
# Delhi                1104       1104        1104    1104     1104  1104
# Jharkhand             380        380         380     380      380   380
# Kerala                453        453         453     453      453   453
# Haryana               452        452         452     452      452   452
# Madhya Pradesh        921        921         921     921      921   921
# Bihar                 434        434         434     434      434   434
# ...

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
# Out:
#    Gender    Amount
# 0  FEMALE  74335853
# 1    MALE  31903664

# %% [markdown]
# ### Statistical Functions

# %%
a=df[['Age','Marital_Status','Orders','Amount']]
a
# Out:
#        Age  Marital_Status  Orders  Amount
# 0       28               0       1   23952
# 1       35               1       3   23934
# 2       35               1       3   23924
# 3       16               0       2   14300
# 4       28               1       2   23877
# ...    ...             ...     ...     ...
# 11246   19               1       4     370
# 11247   33               0       3     367
# 11248   40               0       4     213
# 11249   37               0       3     206
# 11250   19               0       3     188
#
# [11239 rows x 4 columns]

# %%
a.min()
# Out:
# Age                12
# Marital_Status      0
# Orders              1
# Amount            188
# dtype: int64

# %%
a.max()
# Out:
# Age                  92
# Marital_Status        1
# Orders                4
# Amount            23952
# dtype: int64

# %%
a.mean()
# Out:
# Age                 35.410357
# Marital_Status       0.420055
# Orders               2.489634
# Amount            9452.755316
# dtype: float64

# %%
a.mode()
# Out:
#    Age  Marital_Status  Orders  Amount
# 0   30               0       2    7907

# %%
a.var()
# Out:
# Age               1.626611e+02
# Marital_Status    2.436305e-01
# Orders            1.243152e+00
# Amount            2.725648e+07
# dtype: float64

# %%
a.std()
# Out:
# Age                 12.753866
# Marital_Status       0.493589
# Orders               1.114967
# Amount            5220.774000
# dtype: float64

# %%
a.median()
# Out:
# Age                 33.0
# Marital_Status       0.0
# Orders               2.0
# Amount            8109.0
# dtype: float64

# %%
a.describe()
# Out:
#                 Age  Marital_Status        Orders        Amount
# count  11239.000000    11239.000000  11239.000000  11239.000000
# mean      35.410357        0.420055      2.489634   9452.755316
# std       12.753866        0.493589      1.114967   5220.774000
# min       12.000000        0.000000      1.000000    188.000000
# 25%       27.000000        0.000000      2.000000   5443.000000
# 50%       33.000000        0.000000      2.000000   8109.000000
# 75%       43.000000        1.000000      3.000000  12675.000000
# max       92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# ### Visualization

# %%
import matplotlib as mpl
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import scale

# %%
si=SimpleImputer(strategy="median")
si.fit_transform(a)
# Out:
# array([[2.8000e+01, 0.0000e+00, 1.0000e+00, 2.3952e+04],
#        [3.5000e+01, 1.0000e+00, 3.0000e+00, 2.3934e+04],
#        [3.5000e+01, 1.0000e+00, 3.0000e+00, 2.3924e+04],
#        ...,
#        [4.0000e+01, 0.0000e+00, 4.0000e+00, 2.1300e+02],
#        [3.7000e+01, 0.0000e+00, 3.0000e+00, 2.0600e+02],
#        [1.9000e+01, 0.0000e+00, 3.0000e+00, 1.8800e+02]])

# %%
si=SimpleImputer(strategy="most_frequent")
si.fit_transform(a)
# Out:
# array([[   28,     0,     1, 23952],
#        [   35,     1,     3, 23934],
#        [   35,     1,     3, 23924],
#        ...,
#        [   40,     0,     4,   213],
#        [   37,     0,     3,   206],
#        [   19,     0,     3,   188]], dtype=int64)

# %%
# kernel density plot to display how raw data is distributed
sns.kdeplot(a['Amount'])
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
b=scale(df['Age'])
b
# Out:
# array([-0.58105413, -0.03217652, -0.03217652, ...,  0.35987891,
#         0.12464565, -1.2867539 ])

# %%
mnscl=MinMaxScaler()

# %%
mnscale=mnscl.fit_transform(a)
mnscale
# Out:
# array([[2.00000000e-01, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [2.87500000e-01, 1.00000000e+00, 6.66666667e-01, 9.99242552e-01],
#        [2.87500000e-01, 1.00000000e+00, 6.66666667e-01, 9.98821747e-01],
#        ...,
#        [3.50000000e-01, 0.00000000e+00, 1.00000000e+00, 1.05201145e-03],
#        [3.12500000e-01, 0.00000000e+00, 6.66666667e-01, 7.57448241e-04],
#        [8.75000000e-02, 0.00000000e+00, 6.66666667e-01, 0.00000000e+00]])

# %%
n=Normalizer()

# %%
nor_data=n.fit_transform(a)
nor_data
# Out:
# array([[1.16900388e-03, 0.00000000e+00, 4.17501384e-05, 9.99999316e-01],
#        [1.46235323e-03, 4.17815209e-05, 1.25344563e-04, 9.99998922e-01],
#        [1.46296448e-03, 4.17989852e-05, 1.25396956e-04, 9.99998921e-01],
#        ...,
#        [1.84535691e-01, 0.00000000e+00, 1.84535691e-02, 9.82652555e-01],
#        [1.76764591e-01, 0.00000000e+00, 1.43322641e-02, 9.84148803e-01],
#        [1.00538952e-01, 0.00000000e+00, 1.58745714e-02, 9.94806472e-01]])

# %%
sns.lineplot(x='Age',y='Age_Grp',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Age_Grp'>

# %%
ax = sns.countplot(x= 'Gender', data = df)
for bars in ax.containers :
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'Age_Grp', hue = 'Gender')

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(17,8)})
sns.barplot(data = sales_state, x = 'State', y = 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sns.catplot(x="Age_Grp",y="Amount",data=df)

# %%
x=df['Product_Category'].value_counts()
plt.figure(figsize=(10,8))
plt.bar(x.index,x.values,color='r')
plt.xlabel("Product_name")
plt.ylabel("Product_count")
plt.show()

# %%
x=df['State'].value_counts()
plt.figure(figsize=(10,6))
plt.barh(x.index,x.values,color='g')
plt.xlabel("State_Count")
plt.ylabel("State_Name")
plt.show()

# %%
figl, axl = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Age_Grp",y="Amount",data=df)
plt.title('Box-plot')
# Out:
# Text(0.5, 1.0, 'Box-plot')

# %%
plt.figure(figsize=(10,6))
sns.pairplot(a)
plt.show()

# %%
corr=a.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
s=df['Status'].value_counts()
lables=['Successful','Failed']
plt.pie(s,explode=[0.0,0.1],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x250e91e61a0>,
# ...
#  [Text(-1.0993812313926068, 0.03689048741445273, ''),
#   Text(1.199324980643008, -0.04024414001626664, '')],
#  [Text(-0.5996624898505127, 0.02012208404424694, '98.9%'),
#   Text(0.6996062387084212, -0.023475748342822206, '1.1%')])

# %%
f=df['Occupation'].value_counts()
plt.figure(figsize=(10,6))
plt.pie(f.values,labels=f.index,autopct='%1.1f%%')
plt.axis('equal')
plt.title('Occupation')
plt.show()

# %%
sns.heatmap(a.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.set(rc={'figure.figsize':(26,8)})
ax = sns.countplot(data = df, x = 'Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sns.catplot(x="Age",y='Orders',data=a,kind="bar")

# %%
sns.jointplot(x='Zone',y='Orders',data=df,color='g')

# %%
sns.pairplot(a,hue='Orders',palette='husl')

# %%
sns.pairplot(df,vars=["Gender"])
